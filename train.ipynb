# %%
import cv2
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import normalize
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import to_categorical

image_directory='C:/Users/MAAB/Downloads/New folder (3)/'

no_tumor_images=os.listdir(image_directory+ 'no/')
yes_tumor_images=os.listdir(image_directory+ 'yes/')
dataset=[]
label=[]

INPUT_SIZE=64
# print(no_tumor_images)

# path='no0.jpg'

# print(path.split('.')[1])

for i , image_name in enumerate(no_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'no/'+image_name)
        image=Image.fromarray(image,'RGB')
        image=image.resize((INPUT_SIZE,INPUT_SIZE))
        dataset.append(np.array(image))
        label.append(0)

for i , image_name in enumerate(yes_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'yes/'+image_name)
        image=Image.fromarray(image, 'RGB')
        image=image.resize((INPUT_SIZE,INPUT_SIZE))
        dataset.append(np.array(image))
        label.append(1)

dataset=np.array(dataset)
label=np.array(label)


x_train, x_test, y_train, y_test=train_test_split(dataset, label, test_size=0.2, random_state=0)

# Reshape = (n, image_width, image_height, n_channel)

# print(x_train.shape)
# print(y_train.shape)

# print(x_test.shape)
# print(y_test.shape)

x_train=normalize(x_train, axis=1)
x_test=normalize(x_test, axis=1)

y_train=to_categorical(y_train , num_classes=2)
y_test=to_categorical(y_test , num_classes=2)



# Model Building
# 64,64,3

model=Sequential()

model.add(Conv2D(32, (3,3), input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64, (3,3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))


# Binary CrossEntropy= 1, sigmoid
# Categorical Cross Entryopy= 2 , softmax

model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])


model.fit(x_train, y_train, 
batch_size=16, 
verbose=1, epochs=100, 
validation_data=(x_test, y_test),
shuffle=False)
model.save('BrainTumor10EpochsCategorical.h5')
# Out:
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.6233 - loss: 0.6408 - val_accuracy: 0.7600 - val_loss: 0.4851
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8110 - loss: 0.4401 - val_accuracy: 0.8433 - val_loss: 0.3454
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8651 - loss: 0.3286 - val_accuracy: 0.8817 - val_loss: 0.2879
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9039 - loss: 0.2429 - val_accuracy: 0.9300 - val_loss: 0.1942
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9400 - loss: 0.1697 - val_accuracy: 0.9567 - val_loss: 0.1417
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9612 - loss: 0.1136 - val_accuracy: 0.9500 - val_loss: 0.1174
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9738 - loss: 0.0816 - val_accuracy: 0.9617 - val_loss: 0.0875
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9814 - loss: 0.0615 - val_accuracy: 0.9600 - val_loss: 0.1136
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9858 - loss: 0.0376 - val_accuracy: 0.9700 - val_loss: 0.1020
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9905 - loss: 0.0277 - val_accuracy: 0.9683 - val_loss: 0.1148
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9870 - loss: 0.0349 - val_accuracy: 0.9700 - val_loss: 0.1332
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9869 - loss: 0.0305 - val_accuracy: 0.9817 - val_loss: 0.0828
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9977 - loss: 0.0113 - val_accuracy: 0.9800 - val_loss: 0.0998
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9935 - loss: 0.0189 - val_accuracy: 0.9767 - val_loss: 0.0894
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9947 - loss: 0.0184 - val_accuracy: 0.9817 - val_loss: 0.0993
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9995 - loss: 0.0074 - val_accuracy: 0.9817 - val_loss: 0.0928
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9992 - loss: 0.0037 - val_accuracy: 0.9833 - val_loss: 0.0777
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9850 - val_loss: 0.0644
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9976 - loss: 0.0068 - val_accuracy: 0.9717 - val_loss: 0.1510
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9942 - loss: 0.0196 - val_accuracy: 0.9767 - val_loss: 0.1445
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9912 - loss: 0.0335 - val_accuracy: 0.9850 - val_loss: 0.0898
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9926 - loss: 0.0172 - val_accuracy: 0.9833 - val_loss: 0.0720
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9969 - loss: 0.0085 - val_accuracy: 0.9883 - val_loss: 0.0860
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9983 - loss: 0.0034 - val_accuracy: 0.9800 - val_loss: 0.1296
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 1.0000 - loss: 6.9228e-04 - val_accuracy: 0.9800 - val_loss: 0.1221
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9850 - val_loss: 0.0931
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9999 - loss: 9.9360e-04 - val_accuracy: 0.9850 - val_loss: 0.0956
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9800 - val_loss: 0.1166
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 1.0000 - loss: 6.6620e-04 - val_accuracy: 0.9817 - val_loss: 0.1253
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9833 - val_loss: 0.1263
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9999 - loss: 6.9603e-04 - val_accuracy: 0.9833 - val_loss: 0.1138
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 1.0000 - loss: 3.3223e-04 - val_accuracy: 0.9850 - val_loss: 0.1352
# Epoch 33/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 1.0000 - loss: 1.8040e-04 - val_accuracy: 0.9850 - val_loss: 0.1374
# Epoch 34/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 1.0000 - loss: 1.1173e-04 - val_accuracy: 0.9850 - val_loss: 0.1393
# Epoch 35/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 1.0000 - loss: 2.2925e-04 - val_accuracy: 0.9833 - val_loss: 0.1411
# Epoch 36/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 1.0000 - loss: 1.5736e-04 - val_accuracy: 0.9833 - val_loss: 0.1428
# Epoch 37/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9500 - val_loss: 0.1703
# Epoch 38/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.9439 - loss: 0.1508 - val_accuracy: 0.9850 - val_loss: 0.0836
# Epoch 39/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9966 - loss: 0.0104 - val_accuracy: 0.9800 - val_loss: 0.0955
# Epoch 40/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9997 - loss: 0.0022 - val_accuracy: 0.9867 - val_loss: 0.0825
# Epoch 41/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9833 - val_loss: 0.0992
# Epoch 42/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9850 - val_loss: 0.1025
# Epoch 43/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9984 - loss: 0.0036 - val_accuracy: 0.9733 - val_loss: 0.1052
# Epoch 44/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9989 - loss: 0.0074 - val_accuracy: 0.9767 - val_loss: 0.1182
# Epoch 45/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9955 - loss: 0.0140 - val_accuracy: 0.9717 - val_loss: 0.1249
# Epoch 46/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.9946 - loss: 0.0165 - val_accuracy: 0.9800 - val_loss: 0.1221
# Epoch 47/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9932 - loss: 0.0188 - val_accuracy: 0.9800 - val_loss: 0.1251
# Epoch 48/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9833 - val_loss: 0.1222
# Epoch 49/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.9979 - loss: 0.0046 - val_accuracy: 0.9833 - val_loss: 0.1164
# Epoch 50/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9978 - loss: 0.0038 - val_accuracy: 0.9850 - val_loss: 0.1108
# Epoch 51/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.9920 - loss: 0.0221 - val_accuracy: 0.9767 - val_loss: 0.1102
# Epoch 52/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9833 - val_loss: 0.1636
# Epoch 53/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9973 - loss: 0.0071 - val_accuracy: 0.9850 - val_loss: 0.1332
# Epoch 54/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9992 - loss: 0.0017 - val_accuracy: 0.9850 - val_loss: 0.1382
# Epoch 55/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9817 - val_loss: 0.1307
# Epoch 56/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9967 - loss: 0.0059 - val_accuracy: 0.9767 - val_loss: 0.1674
# Epoch 57/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9800 - val_loss: 0.1458
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9817 - val_loss: 0.1442
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9932 - loss: 0.0234 - val_accuracy: 0.9833 - val_loss: 0.1306
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9978 - loss: 0.0069 - val_accuracy: 0.9783 - val_loss: 0.1363
# Epoch 61/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9975 - loss: 0.0104 - val_accuracy: 0.9867 - val_loss: 0.0711
# Epoch 62/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9982 - loss: 0.0040 - val_accuracy: 0.9817 - val_loss: 0.1321
# Epoch 63/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9717 - val_loss: 0.1788
# Epoch 64/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9974 - loss: 0.0030 - val_accuracy: 0.9833 - val_loss: 0.1128
# Epoch 65/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9909 - loss: 0.0267 - val_accuracy: 0.9733 - val_loss: 0.1290
# Epoch 66/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9988 - loss: 0.0073 - val_accuracy: 0.9867 - val_loss: 0.1062
# Epoch 67/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9833 - val_loss: 0.1261
# Epoch 68/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 4.8971e-04 - val_accuracy: 0.9833 - val_loss: 0.1327
# Epoch 69/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 1.0000 - loss: 3.4970e-04 - val_accuracy: 0.9833 - val_loss: 0.1386
# Epoch 70/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9998 - loss: 9.0840e-04 - val_accuracy: 0.9867 - val_loss: 0.1272
# Epoch 71/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9988 - loss: 0.0016 - val_accuracy: 0.9833 - val_loss: 0.1417
# Epoch 72/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.9750 - val_loss: 0.1850
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9884 - loss: 0.0483 - val_accuracy: 0.9817 - val_loss: 0.1689
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9975 - loss: 0.0047 - val_accuracy: 0.9817 - val_loss: 0.1517
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 6.2188e-04 - val_accuracy: 0.9817 - val_loss: 0.1613
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9990 - loss: 0.0020 - val_accuracy: 0.9817 - val_loss: 0.1781
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 1.0000 - loss: 9.0365e-05 - val_accuracy: 0.9800 - val_loss: 0.1872
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 1.0000 - loss: 5.1366e-04 - val_accuracy: 0.9800 - val_loss: 0.2014
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 1.0000 - loss: 3.0453e-04 - val_accuracy: 0.9833 - val_loss: 0.1786
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 1.0000 - loss: 2.2678e-04 - val_accuracy: 0.9833 - val_loss: 0.1968
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 1.0000 - loss: 6.1808e-05 - val_accuracy: 0.9833 - val_loss: 0.2016
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9996 - loss: 8.6220e-04 - val_accuracy: 0.9833 - val_loss: 0.2028
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 1.0000 - loss: 4.9444e-05 - val_accuracy: 0.9833 - val_loss: 0.2085
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9999 - loss: 6.5011e-04 - val_accuracy: 0.9850 - val_loss: 0.1793
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9900 - loss: 0.0437 - val_accuracy: 0.9767 - val_loss: 0.1568
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9910 - loss: 0.0339 - val_accuracy: 0.9783 - val_loss: 0.1079
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9957 - loss: 0.0090 - val_accuracy: 0.9750 - val_loss: 0.1383
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9800 - val_loss: 0.1731
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9987 - loss: 0.0018 - val_accuracy: 0.9783 - val_loss: 0.1693
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 1.0000 - loss: 1.3066e-04 - val_accuracy: 0.9800 - val_loss: 0.1837
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9783 - val_loss: 0.1792
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9951 - loss: 0.0264 - val_accuracy: 0.9783 - val_loss: 0.1372
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9850 - val_loss: 0.1561
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 1.0000 - loss: 5.4831e-04 - val_accuracy: 0.9833 - val_loss: 0.1637
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 3.0059e-04 - val_accuracy: 0.9833 - val_loss: 0.1750
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 4.5953e-04 - val_accuracy: 0.9817 - val_loss: 0.1785
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 5.3574e-04 - val_accuracy: 0.9817 - val_loss: 0.1812
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 2.7993e-04 - val_accuracy: 0.9800 - val_loss: 0.1944
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 1.6759e-05 - val_accuracy: 0.9800 - val_loss: 0.1950
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 1.0000 - loss: 1.3672e-04 - val_accuracy: 0.9800 - val_loss: 0.1945
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Brain Tumor Classification using Convolutional Neural Network (CNN)
#
# This script demonstrates how to build and train a Convolutional Neural Network (CNN) for classifying images of brain tumors into two categories: "no tumor" and "yes tumor."
#
# ## Libraries Used
#
# - `cv2` (OpenCV): For image processing.
# - `os`: For handling file and directory paths.
# - `tensorflow` and `keras`: For building and training the deep learning model.
# - `PIL` (Pillow): For image handling.
# - `numpy`: For numerical operations.
# - `sklearn.model_selection`: For splitting the dataset into training and testing sets.
#
# ## Image Preprocessing
#
# 1. **Directory Paths and Initialization:**
#    - `image_directory`: Path where images are stored.
#    - `no_tumor_images` and `yes_tumor_images`: Lists of image filenames for each category.
#    - `dataset` and `label`: Lists to store image data and corresponding labels.
#
# 2. **Loading and Resizing Images:**
#    - Iterate over the images in both "no" and "yes" directories.
#    - Check if the file extension is `.jpg`.
#    - Load the image using `cv2`, convert it to RGB format using `PIL`, and resize it to `(64, 64)`.
#    - Append the resized image and its label (0 for "no tumor", 1 for "yes tumor") to `dataset` and `label` lists.
#
# 3. **Conversion to NumPy Arrays:**
#    - Convert `dataset` and `label` lists to NumPy arrays for further processing.
#
# 4. **Data Splitting:**
#    - Split the dataset into training and testing sets using `train_test_split` with 20% of the data reserved for testing.
#
# 5. **Normalization:**
#    - Normalize pixel values of images using `normalize` from Keras to scale pixel values to the range [0, 1].
#
# 6. **One-Hot Encoding:**
#    - Convert labels to one-hot encoded format using `to_categorical`.
#
# ## Model Building
#
# 1. **Model Architecture:**
#    - `Sequential` model: A linear stack of layers.
#    - Convolutional layers:
#      - `Conv2D` with 32 filters, kernel size `(3,3)`, and ReLU activation.
#      - `MaxPooling2D` with pool size `(2,2)`.
#      - Additional `Conv2D` layers with 32 and 64 filters, and `MaxPooling2D`.
#    - Flatten the output and add fully connected (`Dense`) layers:
#      - Dense layer with 64 units and ReLU activation.
#      - Dropout layer with 50% rate to prevent overfitting.
#      - Final Dense layer with 2 units (one for each class) and softmax activation.
#
# 2. **Compilation:**
#    - Loss function: `categorical_crossentropy` (suitable for multi-class classification).
#    - Optimizer: `adam`.
#    - Metrics: Accuracy.
#
# ## Model Training
#
# - Train the model with the training data, specifying:
#   - Batch size: 16
#   - Number of epochs: 10
#   - Validation data: Testing set
#   - Shuffle: False (to maintain the order of data)
#
# ## Model Saving
#
# - Save the trained model to a file named `BrainTumor10EpochsCategorical.h5`.
#
# This code performs all the necessary steps to preprocess image data, build a CNN model, and train it for brain tumor classification. The trained model can be used for making predictions on new images.
